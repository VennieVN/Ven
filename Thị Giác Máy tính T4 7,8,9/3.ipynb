# %%
from PIL import Image

# %%
dir = 'C:/Users/Admin/Desktop/img'

# %%
image_path = dir +'/Anime.jpg'
print(image_path)
# Out:
# C:/Users/Admin/Desktop/img/Anime.jpg

# %%
img1 = Image.open(image_path)

# %%
display(img1)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000>

# %%
print("Định dang ảnh: ", img1.format)
# Out:
# Định dang ảnh:  JPEG

# %%
print("Kích thước hình ảnh: ", img1.size)
# Out:
# Kích thước hình ảnh:  (1000, 1000)

# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
my_dir = 'C:/Users/Admin/Desktop/img'

# %%
imgs =  get_image_list(my_dir)

# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
my_path = 'C:/Users/Admin/Desktop/img/Anime.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000>

# %%
print(img.size)
# Out:
# (1000, 1000)

# %%
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
new_image.save('C:/Users/Admin/Desktop/img/resized_image.png')
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
new_image.save('C:/Users/Admin/Desktop/img/newthumbnail_image.png')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=50x50>
