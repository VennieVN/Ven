# %%
from PIL import Image

# %%
dir = 'C:/Users/Admin/Documents/Thị Giác Máy tính T4 7,8,9/img'

# %%
image_path = dir +'/Anime.jpg'
print(image_path)
# Out:
# C:/Users/Admin/Documents/Thị Giác Máy tính T4 7,8,9/img/Anime.jpg

# %%
img1 = Image.open(image_path)

# %%
display(img1)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x376>

# %%
print("Định dang ảnh: ", img1.format)
# Out:
# Định dang ảnh:  JPEG

# %%
print("Kích thước hình ảnh: ", img1.size)
# Out:
# Kích thước hình ảnh:  (564, 376)

# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
my_dir = 'C:/Users/Admin/Documents/Thị Giác Máy tính T4 7,8,9/img'

# %%
imgs =  get_image_list(my_dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (564, 376)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x376>
# (236, 236)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x236>
# (236, 236)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x236>
# (236, 371)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x371>
# (236, 132)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x132>
# (236, 236)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x236>
# (236, 236)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x236>
# (564, 376)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x376>
# (564, 376)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=564x376>
