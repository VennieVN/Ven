# %%
# Kết nối đến Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import os
from google.colab.patches import cv2_imshow

# %%
path = '/content/drive/MyDrive/TGMT/Model/1721031129_TranAnhHao'
# Hiển thị tất cả thư mục hoặc file
os.listdir(path)
# Out:
# ['image_40.jpg',
#  'image_20.jpg',
#  'image_60.jpg',
#  'image_80.jpg',
#  'image_100.jpg',
#  'image_140.jpg',
#  'image_180.jpg',
#  'image_200.jpg',
#  'image_220.jpg',
#  'image_240.jpg',
#  'image_260.jpg',
#  'image_280.jpg',
#  'image_300.jpg',
#  'image_320.jpg',
#  'image_340.jpg',
#  'image_360.jpg',
#  'image_380.jpg',
#  'image_460.jpg',
#  'image_440.jpg',
#  'image_480.jpg',
#  'image_520.jpg',
#  'image_500.jpg',
#  'image_540.jpg',
#  'image_560.jpg',
#  'image_580.jpg',
#  'image_600.jpg',
#  'image_640.jpg',
#  'image_620.jpg',
#  'image_660.jpg',
#  'image_680.jpg',
#  'image_700.jpg',
#  'image_900.jpg',
#  'image_920.jpg',
#  'image_940.jpg',
#  'image_1020.jpg',
#  'image_1040.jpg',
#  'image_1060.jpg',
#  'image_1140.jpg',
#  'image_1180.jpg',
#  'image_1160.jpg',
#  'image_1200.jpg',
#  'image_1240.jpg',
#  'image_1220.jpg',
#  'image_1260.jpg',
#  'image_1280.jpg',
#  'image_1300.jpg',
#  'image_1320.jpg',
#  'image_1360.jpg',
#  'image_1340.jpg',
#  'image_1380.jpg',
#  'image_1400.jpg',
#  'image_1420.jpg',
#  'image_1440.jpg',
#  'image_1480.jpg',
#  'image_1460.jpg',
#  'image_1500.jpg',
#  'image_1540.jpg',
#  'image_1520.jpg',
#  'image_1560.jpg',
#  'image_1580.jpg',
#  'image_1600.jpg',
#  'image_1620.jpg',
#  'image_1660.jpg',
#  'image_1640.jpg',
#  'image_1680.jpg',
#  'image_1700.jpg',
#  'image_1720.jpg',
#  'image_1740.jpg',
#  'image_1760.jpg',
#  'image_1780.jpg',
#  'image_1800.jpg',
#  'image_1820.jpg',
#  'image_1840.jpg',
#  'image_1860.jpg',
#  'image_1900.jpg',
#  'image_1880.jpg',
#  'image_1920.jpg',
#  'image_1960.jpg',
#  'image_1940.jpg',
#  'image_1980.jpg',
#  'image_2000.jpg',
#  'image_2020.jpg',
#  'image_2040.jpg',
#  'image_2060.jpg',
#  'image_2080.jpg',
#  'image_2100.jpg',
#  'image_2140.jpg',
#  'image_2120.jpg',
#  'image_2160.jpg',
#  'image_2200.jpg',
#  'image_2180.jpg',
#  'image_2220.jpg',
#  'image_2240.jpg',
#  'image_2260.jpg',
#  'image_2280.jpg',
#  'image_2300.jpg',
#  'image_2340.jpg',
#  'image_2320.jpg',
#  'image_2360.jpg',
#  'image_2380.jpg',
#  'image_2400.jpg',
#  'image_2420.jpg',
#  'image_2440.jpg',
#  'image_2460.jpg',
#  'image_2480.jpg',
#  'image_2520.jpg',
#  'image_2500.jpg',
#  'image_2540.jpg',
#  'image_2580.jpg',
#  'image_2560.jpg',
#  'image_2600.jpg',
#  'image_2620.jpg',
#  'image_2640.jpg',
#  'image_2660.jpg',
#  'image_2700.jpg',
#  'image_2680.jpg',
#  'image_2720.jpg',
#  'image_2740.jpg',
#  'image_2760.jpg',
#  'image_2780.jpg',
#  'image_2820.jpg',
#  'image_2800.jpg',
#  'image_2840.jpg',
#  'image_2860.jpg',
#  'image_2880.jpg',
#  'image_2940.jpg',
#  'image_3080.jpg',
#  'image_3100.jpg',
#  'image_3240.jpg',
#  'image_3220.jpg']

# %%
# Hiển thị một ảnh
img = cv2.imread(path + "/image_3240.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>
